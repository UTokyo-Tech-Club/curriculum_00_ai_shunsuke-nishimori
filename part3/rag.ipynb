# %%
# !uv pip install llama-index-readers-file pymupdf
# !uv pip install llama-index-vector-stores-postgres
# !uv pip install llama-index-embeddings-huggingface
# !uv pip install llama-index-llms-llama-cpp
# !uv pip install psycopg2-binary pgvector asyncpg "sqlalchemy[asyncio]" greenlet
# Out:
# Using Python 3.12.7 environment at: /app/.venv
# Resolved 58 packages in 799ms
# ⠙ Preparing packages... (0/20)
# ⠙ Preparing packages... (0/20)---     0 B/27.51 KiB
# deprecated ------------------------------     0 B/9.71 KiB
# ⠙ Preparing packages... (0/20)---     0 B/27.51 KiB
# typing-inspect ------------------------------     0 B/8.62 KiB
# deprecated ------------------------------     0 B/9.71 KiB
# ⠙ Preparing packages... (0/20)---     0 B/27.51 KiB
# mypy-extensions ------------------------------     0 B/4.58 KiB
# typing-inspect ------------------------------     0 B/8.62 KiB
# deprecated ------------------------------     0 B/9.71 KiB
# ⠙ Preparing packages... (0/20)---     0 B/27.51 KiB
# mypy-extensions ------------------------------     0 B/4.58 KiB
# typing-inspect ------------------------------     0 B/8.62 KiB
# deprecated ------------------------------     0 B/9.71 KiB
# dirtyjson  ------------------------------     0 B/24.61 KiB
# ...

# %%
# !uv pip install llama-index-embeddings-azure-openai
# Out:
# Using Python 3.12.7 environment at: /app/.venv
# Resolved 64 packages in 989ms
# ⠙ Preparing packages... (0/11)
# ⠙ Preparing packages... (0/11)----------------     0 B/14.20 KiB
# ⠙ Preparing packages... (0/11)------------ 14.20 KiB/14.20 KiB
# llama-index-llms-openai ------------------------------ 14.20 KiB/14.20 KiB
# ⠙ Preparing packages... (0/11)---     0 B/194.19 KiB
# llama-index-llms-openai ------------------------------ 14.20 KiB/14.20 KiB
# ⠙ Preparing packages... (0/11)--- 14.88 KiB/194.19 KiB
# ⠙ Preparing packages... (0/11)--- 14.88 KiB/194.19 KiB
# ⠙ Preparing packages... (0/11)--- 30.88 KiB/194.19 KiB
# portalocker ------------------------------     0 B/17.99 KiB
# ⠙ Preparing packages... (0/11)--- 30.88 KiB/194.19 KiB
# llama-index-llms-azure-openai ------------------------------     0 B/6.16 KiB
# portalocker ------------------------------     0 B/17.99 KiB
# ⠙ Preparing packages... (0/11)--- 30.88 KiB/194.19 KiB
# ...

# %%
from llama_index.embeddings.huggingface import HuggingFaceEmbedding

embed_model = HuggingFaceEmbedding(model_name="BAAI/bge-small-ja")
# Out:
# No sentence-transformers model found with name BAAI/bge-small-ja. Creating a new one with mean pooling.
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# File /app/.venv/lib/python3.12/site-packages/huggingface_hub/utils/_http.py:406, in hf_raise_for_status(response, endpoint_name)
#     405 try:
# --> 406     response.raise_for_status()
#     407 except HTTPError as e:
#
# File /app/.venv/lib/python3.12/site-packages/requests/models.py:1024, in Response.raise_for_status(self)
#    1023 if http_error_msg:
# -> 1024     raise HTTPError(http_error_msg, response=self)
#
# HTTPError: 401 Client Error: Unauthorized for url: https://huggingface.co/BAAI/bge-small-ja/resolve/main/adapter_config.json
#
# The above exception was the direct cause of the following exception:
#
# RepositoryNotFoundError                   Traceback (most recent call last)
# ...

# %%
from llama_index.llms.llama_cpp import LlamaCPP

model_url = "https://huggingface.co/TheBloke/Llama-2-13B-chat-GGUF/resolve/main/llama-2-13b-chat.Q4_0.gguf"
llm = LlamaCPP(
    model_url=model_url,
    temperature=0.1,
    max_new_tokens=256,
    context_window=3900,
    model_kwargs={"n_gpu_layers": 1},
    verbose=True,
)
